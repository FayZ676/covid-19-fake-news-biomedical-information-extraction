# %%
# INITIALIZE METAMAP

from pymetamap import MetaMap
mm = MetaMap.get_instance('/Users/faizififita/Desktop/Docs/2022-summer-research/metamap/public_mm/bin/metamap16')

# %%
# TEST EXTRACTING ENTITY TYPES

sents = ['Sleep Apnea Obstructive']
concepts,error = mm.extract_concepts(sents,[1,2])
for concept in concepts:
    types = concept.semtypes.strip("[]").split(",") # Returns an iterable list of all semtypes
    for type in types:
        print(type)
# Out:
# dsyn
# ftcn
# medd

# %%
# READ IN DATASET

import pandas as pd

df = pd.read_csv('../data/data.csv')
df = df.dropna(subset=['text', 'label']) # Remove all rows with missing values
df['text'] = df['text'].str.replace(r'[^\w\s]+', '', regex=True) # Remove all punctuation
df['text'] = df['text'].str.encode('ascii', 'ignore').str.decode('ascii') # Remove all non-ASCII chars
df['index'] = df.index
# df = df[:10]

# %%
# DECLARE NEW ENTITY TYPES TO DATAFRAME

df['aapp'] = 0
df['acab'] = 0
df['acty'] = 0
df['aggp'] = 0
df['amas'] = 0
df['amph'] = 0
df['anab'] = 0
df['anim'] = 0
df['anst'] = 0
df['antb'] = 0
df['arch'] = 0
df['bacs'] = 0
df['bact'] = 0
df['bdsu'] = 0
df['bdsy'] = 0
df['bhvr'] = 0
df['biof'] = 0
df['bird'] = 0
df['blor'] = 0
df['bmod'] = 0
df['bodm'] = 0
df['bpoc'] = 0
df['bsoj'] = 0
df['celc'] = 0
df['celf'] = 0
df['cell'] = 0
df['cgab'] = 0
df['chem'] = 0
df['chvf'] = 0
df['chvs'] = 0
df['clas'] = 0
df['clna'] = 0
df['clnd'] = 0
df['cnce'] = 0
df['comd'] = 0
df['crbs'] = 0
df['diap'] = 0
df['dora'] = 0
df['drdd'] = 0
df['dsyn'] = 0
df['edac'] = 0
df['eehu'] = 0
df['elii'] = 0
df['emod'] = 0
df['emst'] = 0
df['enty'] = 0
df['enzy'] = 0
df['euka'] = 0
df['evnt'] = 0
df['famg'] = 0
df['ffas'] = 0
df['fish'] = 0
df['fndg'] = 0
df['fngs'] = 0
df['food'] = 0
df['ftcn'] = 0
df['genf'] = 0
df['geoa'] = 0
df['gngm'] = 0
df['gora'] = 0
df['grpa'] = 0
df['grup'] = 0
df['hcpp'] = 0
df['hcro'] = 0
df['hlcs'] = 0
df['hops'] = 0
df['horm'] = 0
df['humn'] = 0
df['idcn'] = 0
df['imft'] = 0
df['inbe'] = 0
df['inch'] = 0
df['inpo'] = 0
df['inpr'] = 0
df['irda'] = 0
df['lang'] = 0
df['lbpr'] = 0
df['lbtr'] = 0
df['mamm'] = 0
df['mbrt'] = 0
df['mcha'] = 0
df['medd'] = 0
df['menp'] = 0
df['mnob'] = 0
df['mobd'] = 0
df['moft'] = 0
df['mosq'] = 0
df['neop'] = 0
df['nnon'] = 0
df['npop'] = 0
df['nusq'] = 0
df['ocac'] = 0
df['ocdi'] = 0
df['orch'] = 0
df['orga'] = 0
df['orgf'] = 0
df['orgm'] = 0
df['orgt'] = 0
df['ortf'] = 0
df['patf'] = 0
df['phob'] = 0
df['phpr'] = 0
df['phsf'] = 0
df['phsu'] = 0
df['plnt'] = 0
df['podg'] = 0
df['popg'] = 0
df['prog'] = 0
df['pros'] = 0
df['qlco'] = 0
df['qnco'] = 0
df['rcpt'] = 0
df['rept'] = 0
df['resa'] = 0
df['resd'] = 0
df['rnlw'] = 0
df['sbst'] = 0
df['shro'] = 0
df['socb'] = 0
df['sosy'] = 0
df['spco'] = 0
df['tisu'] = 0
df['tmco'] = 0
df['topp'] = 0
df['virs'] = 0
df['vita'] = 0
df['vtbt'] = 0
# Out:
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:100: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['orgt'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:101: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ortf'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:102: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['patf'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:103: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['phob'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:104: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['phpr'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:105: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['phsf'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:106: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['phsu'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:107: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['plnt'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:108: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['podg'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:109: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['popg'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:110: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['prog'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['pros'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:112: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['qlco'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:113: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['qnco'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:114: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['rcpt'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:115: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['rept'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:116: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['resa'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:117: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['resd'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['rnlw'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:119: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['sbst'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['shro'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:121: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['socb'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['sosy'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:123: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['spco'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['tisu'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:125: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['tmco'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['topp'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['virs'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:128: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['vita'] = 0
# /var/folders/ds/b9fq0ww11bd987nj6v04fdcm0000gn/T/ipykernel_6583/357823646.py:129: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['vtbt'] = 0

# %%
# SPLIT DATAFRAME INTO MANAGABLE CHUNKS

df1 = df.iloc[0:90, :]
df2 = df.iloc[91:180, :]
df3 = df.iloc[181:270, :]
df4 = df.iloc[271:360, :]
df5 = df.iloc[361:450, :]
df6 = df.iloc[451:540, :]
df7 = df.iloc[541:630, :]
df8 = df.iloc[631:720, :]
df9 = df.iloc[721:810, :]
df10 = df.iloc[811:900, :]
df11 = df.iloc[901:990, :]
df12 = df.iloc[991:1080, :]
df13 = df.iloc[1081:, :]

# %%
# EXTRACT METAMAP CONCEPTS

def extract_mm_concepts(row):
    sents = [row['text']] # Metamap requries text to be contained in an array

    concepts,error = mm.extract_concepts(sents,[1], word_sense_disambiguation=True)

    # Append concepts to dataframe
    for concept in concepts:
        types = concept.semtypes.strip("[]").split(",") # Returns an iterable list of all semtypes
        for type in types:
            if type == 'aapp':
                row['aapp'] += 1
            if type == 'acab':
                row['acab'] += 1
            if type == 'acty':
                row['acty'] += 1
            if type == 'aggp':
                row['aggp'] += 1
            if type == 'amas':
                row['amas'] += 1
            if type == 'amph':
                row['amph'] += 1
            if type == 'anab':
                row['anab'] += 1
            if type == 'anim':
                row['anim'] += 1
            if type == 'anst':
                row['anst'] += 1
            if type == 'antb':
                row['antb'] += 1
            if type == 'arch':
                row['arch'] += 1
            if type == 'bacs':
                row['bacs'] += 1
            if type == 'bact':
                row['bact'] += 1
            if type == 'bdsu':
                row['bdsu'] += 1
            if type == 'bdsy':
                row['bdsy'] += 1
            if type == 'bhvr':
                row['bhvr'] += 1
            if type == 'biof':
                row['biof'] += 1
            if type == 'bird':
                row['bird'] += 1
            if type == 'blor':
                row['blor'] += 1
            if type == 'bmod':
                row['bmod'] += 1
            if type == 'bodm':
                row['bodm'] += 1
            if type == 'bpoc':
                row['bpoc'] += 1
            if type == 'bsoj':
                row['bsoj'] += 1
            if type == 'celc':
                row['celc'] += 1
            if type == 'celf':
                row['celf'] += 1
            if type == 'cell':
                row['cell'] += 1
            if type == 'cgab':
                row['cgab'] += 1
            if type == 'chem':
                row['chem'] += 1
            if type == 'chvf':
                row['chvf'] += 1
            if type == 'chvs':
                row['chvs'] += 1
            if type == 'clas':
                row['clas'] += 1
            if type == 'clna':
                row['clna'] += 1
            if type == 'clnd':
                row['clnd'] += 1
            if type == 'cnce':
                row['cnce'] += 1
            if type == 'comd':
                row['comd'] += 1
            if type == 'crbs':
                row['crbs'] += 1
            if type == 'diap':
                row['diap'] += 1
            if type == 'dora':
                row['dora'] += 1
            if type == 'drdd':
                row['drdd'] += 1
            if type == 'dsyn':
                row['dsyn'] += 1
            if type == 'edac':
                row['edac'] += 1
            if type == 'eehu':
                row['eehu'] += 1
            if type == 'elii':
                row['elii'] += 1
            if type == 'emod':
                row['emod'] += 1
            if type == 'emst':
                row['emst'] += 1
            if type == 'enty':
                row['enty'] += 1
            if type == 'enzy':
                row['enzy'] += 1
            if type == 'euka':
                row['euka'] += 1
            if type == 'evnt':
                row['evnt'] += 1
            if type == 'famg':
                row['famg'] += 1
            if type == 'ffas':
                row['ffas'] += 1
            if type == 'fish':
                row['fish'] += 1
            if type == 'fndg':
                row['fndg'] += 1
            if type == 'fngs':
                row['fngs'] += 1
            if type == 'food':
                row['food'] += 1
            if type == 'ftcn':
                row['ftcn'] += 1
            if type == 'genf':
                row['genf'] += 1
            if type == 'geoa':
                row['geoa'] += 1
            if type == 'gngm':
                row['gngm'] += 1
            if type == 'gora':
                row['gora'] += 1
            if type == 'grpa':
                row['grpa'] += 1
            if type == 'grup':
                row['grup'] += 1
            if type == 'hcpp':
                row['hcpp'] += 1
            if type == 'hcro':
                row['hcro'] += 1
            if type == 'hlcs':
                row['hlcs'] += 1
            if type == 'hops':
                row['hops'] += 1
            if type == 'horm':
                row['horm'] += 1
            if type == 'humn':
                row['humn'] += 1
            if type == 'idcn':
                row['idcn'] += 1
            if type == 'imft':
                row['imft'] += 1
            if type == 'inbe':
                row['inbe'] += 1
            if type == 'inch':
                row['inch'] += 1
            if type == 'inpo':
                row['inpo'] += 1
            if type == 'inpr':
                row['inpr'] += 1
            if type == 'irda':
                row['irda'] += 1
            if type == 'lang':
                row['lang'] += 1
            if type == 'lbpr':
                row['lbpr'] += 1
            if type == 'lbtr':
                row['lbtr'] += 1
            if type == 'mamm':
                row['mamm'] += 1
            if type == 'mbrt':
                row['mbrt'] += 1
            if type == 'mcha':
                row['mcha'] += 1
            if type == 'medd':
                row['medd'] += 1
            if type == 'menp':
                row['menp'] += 1
            if type == 'mnob':
                row['mnob'] += 1
            if type == 'mobd':
                row['mobd'] += 1
            if type == 'moft':
                row['moft'] += 1
            if type == 'mosq':
                row['mosq'] += 1
            if type == 'neop':
                row['neop'] += 1
            if type == 'nnon':
                row['nnon'] += 1
            if type == 'npop':
                row['npop'] += 1
            if type == 'nusq':
                row['nusq'] += 1
            if type == 'ocac':
                row['ocac'] += 1
            if type == 'ocdi':
                row['ocdi'] += 1
            if type == 'orch':
                row['orch'] += 1
            if type == 'orga':
                row['orga'] += 1
            if type == 'orgf':
                row['orgf'] += 1
            if type == 'orgm':
                row['orgm'] += 1
            if type == 'orgt':
                row['orgt'] += 1
            if type == 'patf':
                row['patf'] += 1
            if type == 'phob':
                row['phob'] += 1
            if type == 'phpr':
                row['phpr'] += 1
            if type == 'phsf':
                row['phsf'] += 1
            if type == 'phsu':
                row['phsu'] += 1
            if type == 'plnt':
                row['plnt'] += 1
            if type == 'podg':
                row['podg'] += 1
            if type == 'popg':
                row['popg'] += 1
            if type == 'prog':
                row['prog'] += 1
            if type == 'pros':
                row['pros'] += 1
            if type == 'qlco':
                row['qlco'] += 1
            if type == 'qnco':
                row['qnco'] += 1
            if type == 'rcpt':
                row['rcpt'] += 1
            if type == 'rept':
                row['rept'] += 1
            if type == 'resa':
                row['resa'] += 1
            if type == 'resd':
                row['resd'] += 1
            if type == 'rnlw':
                row['rnlw'] += 1
            if type == 'sbst':
                row['sbst'] += 1
            if type == 'shro':
                row['shro'] += 1
            if type == 'socb':
                row['socb'] += 1
            if type == 'sosy':
                row['sosy'] += 1
            if type == 'spco':
                row['spco'] += 1
            if type == 'tisu':
                row['tisu'] += 1
            if type == 'tmco':
                row['tmco'] += 1
            if type == 'topp':
                row['topp'] += 1
            if type == 'virs':
                row['virs'] += 1
            if type == 'vita':
                row['vita'] += 1
            if type == 'vtbt':
                row['vtbt'] += 1

    print('done row ' + str(row['index']))
    return row

df_features_1 = df1.apply(lambda row: extract_mm_concepts(row), axis=1)
df_features_2 = df2.apply(lambda row: extract_mm_concepts(row), axis=1)
df_features_3 = df3.apply(lambda row: extract_mm_concepts(row), axis=1)
df_features_4 = df4.apply(lambda row: extract_mm_concepts(row), axis=1)
df_features_5 = df5.apply(lambda row: extract_mm_concepts(row), axis=1)
df_features_6 = df6.apply(lambda row: extract_mm_concepts(row), axis=1)
df_features_7 = df7.apply(lambda row: extract_mm_concepts(row), axis=1)
df_features_8 = df8.apply(lambda row: extract_mm_concepts(row), axis=1)
df_features_9 = df9.apply(lambda row: extract_mm_concepts(row), axis=1)
df_features_10 = df10.apply(lambda row: extract_mm_concepts(row), axis=1)
df_features_11 = df11.apply(lambda row: extract_mm_concepts(row), axis=1)
df_features_12 = df12.apply(lambda row: extract_mm_concepts(row), axis=1)
df_features_13 = df13.apply(lambda row: extract_mm_concepts(row), axis=1)
# Out:
# done row 0
# done row 1
# done row 2
# done row 3
# done row 4
# done row 6
# done row 7
# done row 8
# done row 9
# done row 10

# %%
    # duplicates = df[df.duplicated('pos_info')] # Check for duplicate concepts
    # max_score = duplicates['score'].idxmax()

# %%
# df_features.to_csv('../data/datasets/metamap.csv')
