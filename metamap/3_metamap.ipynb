# %%
# INITIALIZE METAMAP

from pymetamap import MetaMap
mm = MetaMap.get_instance('/Users/faizififita/Desktop/Docs/2022-summer-research/metamap/public_mm/bin/metamap16')

# %%
# TEST EXTRACTING ENTITY TYPES

sents = ['Sleep Apnea Obstructive']
concepts,error = mm.extract_concepts(sents,[1,2])
for concept in concepts:
    types = concept.semtypes.strip("[]").split(",") # Returns an iterable list of all semtypes
    for type in types:
        print(type)
# Out:
# dsyn
# ftcn
# medd

# %%
# READ IN DATASET

import pandas as pd

df = pd.read_csv('../data/data.csv')
df = df.dropna(subset=['text', 'label']) # Remove all rows with missing values
df['text'] = df['text'].str.replace(r'[^\w\s]+', '', regex=True) # Remove all punctuation
df['text'] = df['text'].str.encode('ascii', 'ignore').str.decode('ascii') # Remove all non-ASCII chars
df['index'] = df.index
# df = df[:10]

# %%
# DECLARE NEW ENTITY TYPES TO DATAFRAME

df['aapp'] = 0
df['acab'] = 0
df['acty'] = 0
df['aggp'] = 0
df['amas'] = 0
df['amph'] = 0
df['anab'] = 0
df['anim'] = 0
df['anst'] = 0
df['antb'] = 0
df['arch'] = 0
df['bacs'] = 0
df['bact'] = 0
df['bdsu'] = 0
df['bdsy'] = 0
df['bhvr'] = 0
df['biof'] = 0
df['bird'] = 0
df['blor'] = 0
df['bmod'] = 0
df['bodm'] = 0
df['bpoc'] = 0
df['bsoj'] = 0
df['celc'] = 0
df['celf'] = 0
df['cell'] = 0
df['cgab'] = 0
df['chem'] = 0
df['chvf'] = 0
df['chvs'] = 0
df['clas'] = 0
df['clna'] = 0
df['clnd'] = 0
df['cnce'] = 0
df['comd'] = 0
df['crbs'] = 0
df['diap'] = 0
df['dora'] = 0
df['drdd'] = 0
df['dsyn'] = 0
df['edac'] = 0
df['eehu'] = 0
df['elii'] = 0
df['emod'] = 0
df['emst'] = 0
df['enty'] = 0
df['enzy'] = 0
df['euka'] = 0
df['evnt'] = 0
df['famg'] = 0
df['ffas'] = 0
df['fish'] = 0
df['fndg'] = 0
df['fngs'] = 0
df['food'] = 0
df['ftcn'] = 0
df['genf'] = 0
df['geoa'] = 0
df['gngm'] = 0
df['gora'] = 0
df['grpa'] = 0
df['grup'] = 0
df['hcpp'] = 0
df['hcro'] = 0
df['hlcs'] = 0
df['hops'] = 0
df['horm'] = 0
df['humn'] = 0
df['idcn'] = 0
df['imft'] = 0
df['inbe'] = 0
df['inch'] = 0
df['inpo'] = 0
df['inpr'] = 0
df['irda'] = 0
df['lang'] = 0
df['lbpr'] = 0
df['lbtr'] = 0
df['mamm'] = 0
df['mbrt'] = 0
df['mcha'] = 0
df['medd'] = 0
df['menp'] = 0
df['mnob'] = 0
df['mobd'] = 0
df['moft'] = 0
df['mosq'] = 0
df['neop'] = 0
df['nnon'] = 0
df['npop'] = 0
df['nusq'] = 0
df['ocac'] = 0
df['ocdi'] = 0
df['orch'] = 0
df['orga'] = 0
df['orgf'] = 0
df['orgm'] = 0
df['orgt'] = 0
df['ortf'] = 0
df['patf'] = 0
df['phob'] = 0
df['phpr'] = 0
df['phsf'] = 0
df['phsu'] = 0
df['plnt'] = 0
df['podg'] = 0
df['popg'] = 0
df['prog'] = 0
df['pros'] = 0
df['qlco'] = 0
df['qnco'] = 0
df['rcpt'] = 0
df['rept'] = 0
df['resa'] = 0
df['resd'] = 0
df['rnlw'] = 0
df['sbst'] = 0
df['shro'] = 0
df['socb'] = 0
df['sosy'] = 0
df['spco'] = 0
df['tisu'] = 0
df['tmco'] = 0
df['topp'] = 0
df['virs'] = 0
df['vita'] = 0
df['vtbt'] = 0

# %%
# SPLIT DATAFRAME INTO CHUNKS TO AVOID RESOURCE ERROR

df1 = df.iloc[0:90, :]
df2 = df.iloc[90:180, :]
df3_1 = df.iloc[180:207, :]
df3_2 = df.iloc[207:208, :]
df3_3 = df.iloc[208:270, :]
df4 = df.iloc[270:360, :]
df5 = df.iloc[360:450, :]
df6 = df.iloc[450:540, :]
df7 = df.iloc[540:630, :]
df8 = df.iloc[630:720, :]
df9 = df.iloc[720:810, :]
df10 = df.iloc[810:900, :]
df11 = df.iloc[900:990, :]
df12 = df.iloc[990:1080, :]
df13 = df.iloc[1080:, :]

# %%
# EXTRACT METAMAP CONCEPTS

def extract_mm_concepts(row):
    sents = [row['text']] # Metamap requries text to be contained in an array

    # Execution is faster if stop words are removed before extraction.
    concepts,error = mm.extract_concepts(sents, [1], word_sense_disambiguation=True, ignore_stop_phrases=True, composite_phrase=0, prune=20)
    # Append concepts to dataframe
    for concept in concepts:
        types = concept.semtypes.strip("[]").split(",") # Returns an iterable list of all semtypes
        for type in types:
            if type == 'aapp':
                row['aapp'] += 1
            if type == 'acab':
                row['acab'] += 1
            if type == 'acty':
                row['acty'] += 1
            if type == 'aggp':
                row['aggp'] += 1
            if type == 'amas':
                row['amas'] += 1
            if type == 'amph':
                row['amph'] += 1
            if type == 'anab':
                row['anab'] += 1
            if type == 'anim':
                row['anim'] += 1
            if type == 'anst':
                row['anst'] += 1
            if type == 'antb':
                row['antb'] += 1
            if type == 'arch':
                row['arch'] += 1
            if type == 'bacs':
                row['bacs'] += 1
            if type == 'bact':
                row['bact'] += 1
            if type == 'bdsu':
                row['bdsu'] += 1
            if type == 'bdsy':
                row['bdsy'] += 1
            if type == 'bhvr':
                row['bhvr'] += 1
            if type == 'biof':
                row['biof'] += 1
            if type == 'bird':
                row['bird'] += 1
            if type == 'blor':
                row['blor'] += 1
            if type == 'bmod':
                row['bmod'] += 1
            if type == 'bodm':
                row['bodm'] += 1
            if type == 'bpoc':
                row['bpoc'] += 1
            if type == 'bsoj':
                row['bsoj'] += 1
            if type == 'celc':
                row['celc'] += 1
            if type == 'celf':
                row['celf'] += 1
            if type == 'cell':
                row['cell'] += 1
            if type == 'cgab':
                row['cgab'] += 1
            if type == 'chem':
                row['chem'] += 1
            if type == 'chvf':
                row['chvf'] += 1
            if type == 'chvs':
                row['chvs'] += 1
            if type == 'clas':
                row['clas'] += 1
            if type == 'clna':
                row['clna'] += 1
            if type == 'clnd':
                row['clnd'] += 1
            if type == 'cnce':
                row['cnce'] += 1
            if type == 'comd':
                row['comd'] += 1
            if type == 'crbs':
                row['crbs'] += 1
            if type == 'diap':
                row['diap'] += 1
            if type == 'dora':
                row['dora'] += 1
            if type == 'drdd':
                row['drdd'] += 1
            if type == 'dsyn':
                row['dsyn'] += 1
            if type == 'edac':
                row['edac'] += 1
            if type == 'eehu':
                row['eehu'] += 1
            if type == 'elii':
                row['elii'] += 1
            if type == 'emod':
                row['emod'] += 1
            if type == 'emst':
                row['emst'] += 1
            if type == 'enty':
                row['enty'] += 1
            if type == 'enzy':
                row['enzy'] += 1
            if type == 'euka':
                row['euka'] += 1
            if type == 'evnt':
                row['evnt'] += 1
            if type == 'famg':
                row['famg'] += 1
            if type == 'ffas':
                row['ffas'] += 1
            if type == 'fish':
                row['fish'] += 1
            if type == 'fndg':
                row['fndg'] += 1
            if type == 'fngs':
                row['fngs'] += 1
            if type == 'food':
                row['food'] += 1
            if type == 'ftcn':
                row['ftcn'] += 1
            if type == 'genf':
                row['genf'] += 1
            if type == 'geoa':
                row['geoa'] += 1
            if type == 'gngm':
                row['gngm'] += 1
            if type == 'gora':
                row['gora'] += 1
            if type == 'grpa':
                row['grpa'] += 1
            if type == 'grup':
                row['grup'] += 1
            if type == 'hcpp':
                row['hcpp'] += 1
            if type == 'hcro':
                row['hcro'] += 1
            if type == 'hlcs':
                row['hlcs'] += 1
            if type == 'hops':
                row['hops'] += 1
            if type == 'horm':
                row['horm'] += 1
            if type == 'humn':
                row['humn'] += 1
            if type == 'idcn':
                row['idcn'] += 1
            if type == 'imft':
                row['imft'] += 1
            if type == 'inbe':
                row['inbe'] += 1
            if type == 'inch':
                row['inch'] += 1
            if type == 'inpo':
                row['inpo'] += 1
            if type == 'inpr':
                row['inpr'] += 1
            if type == 'irda':
                row['irda'] += 1
            if type == 'lang':
                row['lang'] += 1
            if type == 'lbpr':
                row['lbpr'] += 1
            if type == 'lbtr':
                row['lbtr'] += 1
            if type == 'mamm':
                row['mamm'] += 1
            if type == 'mbrt':
                row['mbrt'] += 1
            if type == 'mcha':
                row['mcha'] += 1
            if type == 'medd':
                row['medd'] += 1
            if type == 'menp':
                row['menp'] += 1
            if type == 'mnob':
                row['mnob'] += 1
            if type == 'mobd':
                row['mobd'] += 1
            if type == 'moft':
                row['moft'] += 1
            if type == 'mosq':
                row['mosq'] += 1
            if type == 'neop':
                row['neop'] += 1
            if type == 'nnon':
                row['nnon'] += 1
            if type == 'npop':
                row['npop'] += 1
            if type == 'nusq':
                row['nusq'] += 1
            if type == 'ocac':
                row['ocac'] += 1
            if type == 'ocdi':
                row['ocdi'] += 1
            if type == 'orch':
                row['orch'] += 1
            if type == 'orga':
                row['orga'] += 1
            if type == 'orgf':
                row['orgf'] += 1
            if type == 'orgm':
                row['orgm'] += 1
            if type == 'orgt':
                row['orgt'] += 1
            if type == 'patf':
                row['patf'] += 1
            if type == 'phob':
                row['phob'] += 1
            if type == 'phpr':
                row['phpr'] += 1
            if type == 'phsf':
                row['phsf'] += 1
            if type == 'phsu':
                row['phsu'] += 1
            if type == 'plnt':
                row['plnt'] += 1
            if type == 'podg':
                row['podg'] += 1
            if type == 'popg':
                row['popg'] += 1
            if type == 'prog':
                row['prog'] += 1
            if type == 'pros':
                row['pros'] += 1
            if type == 'qlco':
                row['qlco'] += 1
            if type == 'qnco':
                row['qnco'] += 1
            if type == 'rcpt':
                row['rcpt'] += 1
            if type == 'rept':
                row['rept'] += 1
            if type == 'resa':
                row['resa'] += 1
            if type == 'resd':
                row['resd'] += 1
            if type == 'rnlw':
                row['rnlw'] += 1
            if type == 'sbst':
                row['sbst'] += 1
            if type == 'shro':
                row['shro'] += 1
            if type == 'socb':
                row['socb'] += 1
            if type == 'sosy':
                row['sosy'] += 1
            if type == 'spco':
                row['spco'] += 1
            if type == 'tisu':
                row['tisu'] += 1
            if type == 'tmco':
                row['tmco'] += 1
            if type == 'topp':
                row['topp'] += 1
            if type == 'virs':
                row['virs'] += 1
            if type == 'vita':
                row['vita'] += 1
            if type == 'vtbt':
                row['vtbt'] += 1

    print('done row ' + str(row['index']))
    return row
# Out:
# done row 643
# done row 644
# done row 645
# done row 646
# done row 647
# done row 648
# done row 649
# done row 650
# done row 651
# done row 652
# done row 653
# done row 654
# done row 655
# done row 656
# done row 657
# done row 658
# done row 659
# done row 660
# done row 661
# done row 662
# done row 663
# done row 664
# done row 665
# done row 666
# done row 667
# done row 668
# done row 669
# done row 670
# done row 671
# done row 672
# done row 673
# done row 674
# done row 675
# done row 676
# done row 677
# done row 678
# done row 679
# done row 680
# done row 681
# done row 682
# done row 683
# done row 684
# done row 685
# done row 686
# done row 687
# done row 688
# done row 689
# done row 690
# done row 691
# done row 692
# done row 693
# done row 694
# done row 695
# done row 696
# done row 697
# done row 698
# done row 699
# done row 700
# done row 701
# done row 702
# done row 703
# done row 704
# done row 705
# done row 706
# done row 707
# done row 708
# ...

# %%
# EXECUTE ON CHUNKS

# df_features_1 = df1.apply(lambda row: extract_mm_concepts(row), axis=1)
# df_features_2 = df2.apply(lambda row: extract_mm_concepts(row), axis=1)
# df_features_3_1 = df3_1.apply(lambda row: extract_mm_concepts(row), axis=1)
# df_features_3_2 = df3_2.apply(lambda row: extract_mm_concepts(row), axis=1)
# df_features_3_3 = df3_3.apply(lambda row: extract_mm_concepts(row), axis=1)
# df_features_4 = df4.apply(lambda row: extract_mm_concepts(row), axis=1)
# df_features_5 = df5.apply(lambda row: extract_mm_concepts(row), axis=1)
# df_features_6 = df6.apply(lambda row: extract_mm_concepts(row), axis=1)
# df_features_7 = df7.apply(lambda row: extract_mm_concepts(row), axis=1)
# df_features_8 = df8.apply(lambda row: extract_mm_concepts(row), axis=1)
# df_features_9 = df9.apply(lambda row: extract_mm_concepts(row), axis=1)
# df_features_10 = df10.apply(lambda row: extract_mm_concepts(row), axis=1)
# df_features_11 = df11.apply(lambda row: extract_mm_concepts(row), axis=1)
# df_features_12 = df12.apply(lambda row: extract_mm_concepts(row), axis=1)
# df_features_13 = df13.apply(lambda row: extract_mm_concepts(row), axis=1)

# %%
# ALTERNATIVE APPROACH
# We can extract the metamap concepts in bulk since the resource
# error can be avoided by fine tuning'extract_concepts'

df_features = df.apply(lambda row: extract_mm_concepts(row), axis=1)
