# %%
from pymetamap import MetaMap
mm = MetaMap.get_instance('/Users/faizififita/Desktop/Docs/2022-summer-research/metamap/public_mm/bin/metamap16')

# %%
sents = ['Heart Attack', 'John had a huge heart attack']
concepts,error = mm.extract_concepts(sents,[1,2], word_sense_disambiguation=True)
for concept in concepts:
    for type in concept.semtypes:
        print(type)
# Out:
# [
# d
# s
# y
# n
# ]
# [
# d
# s
# y
# n
# ]

# %%
import pandas as pd

df = pd.read_csv('../data/data.csv')
df = df.dropna(subset=['text', 'label'])
df['index'] = df.index
# df = df[:10]
df.head()
# Out:
#                                                title  \
# 0  Due to the recent outbreak for the Coronavirus...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                 text  \
# 0  You just need to add water, and the drugs and ...
# 1  Hydroxychloroquine has been shown to have a 10...
# 2  Fact: Hydroxychloroquine has been shown to hav...
# 3  The Corona virus is a man made virus created i...
# 4  Doesn’t @BillGates finance research at the Wuh...
#
#                       source label  index
# 0  coronavirusmedicalkit.com  Fake      0
# 1               RudyGiuliani  Fake      1
# 2                CharlieKirk  Fake      2
# 3    JoanneWrightForCongress  Fake      3
# 4    JoanneWrightForCongress  Fake      4

# %%
mm.extract_concepts(sentences=[], word_sense_disambiguation=True, )

# %%
# DECLARE NEW ENTITY TYPES TO DATAFRAME

df['aapp'] = 0
df['acab'] = 0
df['acty'] = 0
df['aggp'] = 0
df['amas'] = 0
df['amph'] = 0
df['anab'] = 0
df['anim'] = 0
df['anst'] = 0
df['antb'] = 0
df['arch'] = 0
df['bacs'] = 0
df['bact'] = 0
df['bdsu'] = 0
df['bdsy'] = 0
df['bhvr'] = 0
df['biof'] = 0
df['bird'] = 0
df['blor'] = 0
df['bmod'] = 0
df['bodm'] = 0
df['bpoc'] = 0
df['bsoj'] = 0
df['celc'] = 0
df['celf'] = 0
df['cell'] = 0
df['cgab'] = 0
df['chem'] = 0
df['chvf'] = 0
df['chvs'] = 0
df['clas'] = 0
df['clna'] = 0
df['clnd'] = 0
df['cnce'] = 0
df['comd'] = 0
df['crbs'] = 0
df['diap'] = 0
df['dora'] = 0
df['drdd'] = 0
df['dsyn'] = 0
df['edac'] = 0
df['eehu'] = 0
df['elii'] = 0
df['emod'] = 0
df['emst'] = 0
df['enty'] = 0
df['enzy'] = 0
df['euka'] = 0
df['evnt'] = 0
df['famg'] = 0
df['ffas'] = 0
df['fish'] = 0
df['fndg'] = 0
df['fngs'] = 0
df['food'] = 0
df['ftcn'] = 0
df['genf'] = 0
df['geoa'] = 0
df['gngm'] = 0
df['gora'] = 0
df['grpa'] = 0
df['grup'] = 0
df['hcpp'] = 0
df['hcro'] = 0
df['hlcs'] = 0
df['hops'] = 0
df['horm'] = 0
df['humn'] = 0
df['idcn'] = 0
df['imft'] = 0
df['inbe'] = 0
df['inch'] = 0
df['inpo'] = 0
df['inpr'] = 0
df['irda'] = 0
df['lang'] = 0
df['lbpr'] = 0
df['lbtr'] = 0
df['mamm'] = 0
df['mbrt'] = 0
df['mcha'] = 0
df['medd'] = 0
df['menp'] = 0
df['mnob'] = 0
df['mobd'] = 0
df['moft'] = 0
df['mosq'] = 0
df['neop'] = 0
df['nnon'] = 0
df['npop'] = 0
df['nusq'] = 0
df['ocac'] = 0
df['ocdi'] = 0
df['orch'] = 0
df['orga'] = 0
df['orgf'] = 0
df['orgm'] = 0
df['orgt'] = 0
df['ortf'] = 0
df['patf'] = 0
df['phob'] = 0
df['phpr'] = 0
df['phsf'] = 0
df['phsu'] = 0
df['plnt'] = 0
df['podg'] = 0
df['popg'] = 0
df['prog'] = 0
df['pros'] = 0
df['qlco'] = 0
df['qnco'] = 0
df['rcpt'] = 0
df['rept'] = 0
df['resa'] = 0
df['resd'] = 0
df['rnlw'] = 0
df['sbst'] = 0
df['shro'] = 0
df['socb'] = 0
df['sosy'] = 0
df['spco'] = 0
df['tisu'] = 0
df['tmco'] = 0
df['topp'] = 0
df['virs'] = 0
df['vita'] = 0
df['vtbt'] = 0

# %%
import re

# EXTRACT METAMAP CONCEPTS

def extract_mm_concepts(row):
    text = re.sub(r'[^\w\s]', '', row['text']) # Metamap is punctuation sensitive
    sents = [text] # Metamap requries text to be contained in an array

    concepts,error = mm.extract_concepts(sents,[1], word_sense_disambiguation=True)

    for concept in concepts: # Append all concepts to a dataframe
        for type in concept.semtypes:
            if concept.semtypes == '[aapp]':
                row['aapp'] += 1
            if concept.semtypes == '[acab]':
                row['acab'] += 1
            if concept.semtypes == '[acty]':
                row['acty'] += 1
            if concept.semtypes == '[aggp]':
                row['aggp'] += 1
            if concept.semtypes == '[amas]':
                row['amas'] += 1
            if concept.semtypes == '[amph]':
                row['amph'] += 1
            if concept.semtypes == '[anab]':
                row['anab'] += 1
            if concept.semtypes == '[anim]':
                row['anim'] += 1
            if concept.semtypes == '[anst]':
                row['anst'] += 1
            if concept.semtypes == '[antb]':
                row['antb'] += 1
            if concept.semtypes == '[arch]':
                row['arch'] += 1
            if concept.semtypes == '[bacs]':
                row['bacs'] += 1
            if concept.semtypes == '[bact]':
                row['bact'] += 1
            if concept.semtypes == '[bdsu]':
                row['bdsu'] += 1
            if concept.semtypes == '[bdsy]':
                row['bdsy'] += 1
            if concept.semtypes == '[bhvr]':
                row['bhvr'] += 1
            if concept.semtypes == '[biof]':
                row['biof'] += 1
            if concept.semtypes == '[bird]':
                row['bird'] += 1
            if concept.semtypes == '[blor]':
                row['blor'] += 1
            if concept.semtypes == '[bmod]':
                row['bmod'] += 1
            if concept.semtypes == '[bodm]':
                row['bodm'] += 1
            if concept.semtypes == '[bpoc]':
                row['bpoc'] += 1
            if concept.semtypes == '[bsoj]':
                row['bsoj'] += 1
            if concept.semtypes == '[celc]':
                row['celc'] += 1
            if concept.semtypes == '[celf]':
                row['celf'] += 1
            if concept.semtypes == '[cell]':
                row['cell'] += 1
            if concept.semtypes == '[cgab]':
                row['cgab'] += 1
            if concept.semtypes == '[chem]':
                row['chem'] += 1
            if concept.semtypes == '[chvf]':
                row['chvf'] += 1
            if concept.semtypes == '[chvs]':
                row['chvs'] += 1
            if concept.semtypes == '[clas]':
                row['clas'] += 1
            if concept.semtypes == '[clna]':
                row['clna'] += 1
            if concept.semtypes == '[clnd]':
                row['clnd'] += 1
            if concept.semtypes == '[cnce]':
                row['cnce'] += 1
            if concept.semtypes == '[comd]':
                row['comd'] += 1
            if concept.semtypes == '[crbs]':
                row['crbs'] += 1
            if concept.semtypes == '[diap]':
                row['diap'] += 1
            if concept.semtypes == '[dora]':
                row['dora'] += 1
            if concept.semtypes == '[drdd]':
                row['drdd'] += 1
            if concept.semtypes == '[dsyn]':
                row['dsyn'] += 1
            if concept.semtypes == '[edac]':
                row['edac'] += 1
            if concept.semtypes == '[eehu]':
                row['eehu'] += 1
            if concept.semtypes == '[elii]':
                row['elii'] += 1
            if concept.semtypes == '[emod]':
                row['emod'] += 1
            if concept.semtypes == '[emst]':
                row['emst'] += 1
            if concept.semtypes == '[enty]':
                row['enty'] += 1
            if concept.semtypes == '[enzy]':
                row['enzy'] += 1
            if concept.semtypes == '[euka]':
                row['euka'] += 1
            if concept.semtypes == '[evnt]':
                row['evnt'] += 1
            if concept.semtypes == '[famg]':
                row['famg'] += 1
            if concept.semtypes == '[ffas]':
                row['ffas'] += 1
            if concept.semtypes == '[fish]':
                row['fish'] += 1
            if concept.semtypes == '[fndg]':
                row['fndg'] += 1
            if concept.semtypes == '[fngs]':
                row['fngs'] += 1
            if concept.semtypes == '[food]':
                row['food'] += 1
            if concept.semtypes == '[ftcn]':
                row['ftcn'] += 1
            if concept.semtypes == '[genf]':
                row['genf'] += 1
            if concept.semtypes == '[geoa]':
                row['geoa'] += 1
            if concept.semtypes == '[gngm]':
                row['gngm'] += 1
            if concept.semtypes == '[gora]':
                row['gora'] += 1
            if concept.semtypes == '[grpa]':
                row['grpa'] += 1
            if concept.semtypes == '[grup]':
                row['grup'] += 1
            if concept.semtypes == '[hcpp]':
                row['hcpp'] += 1
            if concept.semtypes == '[hcro]':
                row['hcro'] += 1
            if concept.semtypes == '[hlcs]':
                row['hlcs'] += 1
            if concept.semtypes == '[hops]':
                row['hops'] += 1
            if concept.semtypes == '[horm]':
                row['horm'] += 1
            if concept.semtypes == '[humn]':
                row['humn'] += 1
            if concept.semtypes == '[idcn]':
                row['idcn'] += 1
            if concept.semtypes == '[imft]':
                row['imft'] += 1
            if concept.semtypes == '[inbe]':
                row['inbe'] += 1
            if concept.semtypes == '[inch]':
                row['inch'] += 1
            if concept.semtypes == '[inpo]':
                row['inpo'] += 1
            if concept.semtypes == '[inpr]':
                row['inpr'] += 1
            if concept.semtypes == '[irda]':
                row['irda'] += 1
            if concept.semtypes == '[lang]':
                row['lang'] += 1
            if concept.semtypes == '[lbpr]':
                row['lbpr'] += 1
            if concept.semtypes == '[lbtr]':
                row['lbtr'] += 1
            if concept.semtypes == '[mamm]':
                row['mamm'] += 1
            if concept.semtypes == '[mbrt]':
                row['mbrt'] += 1
            if concept.semtypes == '[mcha]':
                row['mcha'] += 1
            if concept.semtypes == '[medd]':
                row['medd'] += 1
            if concept.semtypes == '[menp]':
                row['menp'] += 1
            if concept.semtypes == '[mnob]':
                row['mnob'] += 1
            if concept.semtypes == '[mobd]':
                row['mobd'] += 1
            if concept.semtypes == '[moft]':
                row['moft'] += 1
            if concept.semtypes == '[mosq]':
                row['mosq'] += 1
            if concept.semtypes == '[neop]':
                row['neop'] += 1
            if concept.semtypes == '[nnon]':
                row['nnon'] += 1
            if concept.semtypes == '[npop]':
                row['npop'] += 1
            if concept.semtypes == '[nusq]':
                row['nusq'] += 1
            if concept.semtypes == '[ocac]':
                row['ocac'] += 1
            if concept.semtypes == '[ocdi]':
                row['ocdi'] += 1
            if concept.semtypes == '[orch]':
                row['orch'] += 1
            if concept.semtypes == '[orga]':
                row['orga'] += 1
            if concept.semtypes == '[orgf]':
                row['orgf'] += 1
            if concept.semtypes == '[orgm]':
                row['orgm'] += 1
            if concept.semtypes == '[orgt]':
                row['orgt'] += 1
            if concept.semtypes == '[patf]':
                row['patf'] += 1
            if concept.semtypes == '[phob]':
                row['phob'] += 1
            if concept.semtypes == '[phpr]':
                row['phpr'] += 1
            if concept.semtypes == '[phsf]':
                row['phsf'] += 1
            if concept.semtypes == '[phsu]':
                row['phsu'] += 1
            if concept.semtypes == '[plnt]':
                row['plnt'] += 1
            if concept.semtypes == '[podg]':
                row['podg'] += 1
            if concept.semtypes == '[popg]':
                row['popg'] += 1
            if concept.semtypes == '[prog]':
                row['prog'] += 1
            if concept.semtypes == '[pros]':
                row['pros'] += 1
            if concept.semtypes == '[qlco]':
                row['qlco'] += 1
            if concept.semtypes == '[qnco]':
                row['qnco'] += 1
            if concept.semtypes == '[rcpt]':
                row['rcpt'] += 1
            if concept.semtypes == '[rept]':
                row['rept'] += 1
            if concept.semtypes == '[resa]':
                row['resa'] += 1
            if concept.semtypes == '[resd]':
                row['resd'] += 1
            if concept.semtypes == '[rnlw]':
                row['rnlw'] += 1
            if concept.semtypes == '[sbst]':
                row['sbst'] += 1
            if concept.semtypes == '[shro]':
                row['shro'] += 1
            if concept.semtypes == '[socb]':
                row['socb'] += 1
            if concept.semtypes == '[sosy]':
                row['sosy'] += 1
            if concept.semtypes == '[spco]':
                row['spco'] += 1
            if concept.semtypes == '[tisu]':
                row['tisu'] += 1
            if concept.semtypes == '[tmco]':
                row['tmco'] += 1
            if concept.semtypes == '[topp]':
                row['topp'] += 1
            if concept.semtypes == '[virs]':
                row['virs'] += 1
            if concept.semtypes == '[vita]':
                row['vita'] += 1
            if concept.semtypes == '[vtbt]':
                row['vtbt'] += 1

    print('done row ' + str(row['index']))
    return row

df_features = df.apply(lambda row: extract_mm_concepts(row), axis=1)

# %%
    # duplicates = df[df.duplicated('pos_info')] # Check for duplicate concepts
    # max_score = duplicates['score'].idxmax()

# %%
# df_features.to_csv('../data/datasets/metamap.csv')
